# %%
from google.colab import files
import pandas as pd
import numpy as np
import json
import datetime as dt

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1d13add9-8000-453a-8cc4-8301f6bf3f69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d13add9-8000-453a-8cc4-8301f6bf3f69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('test_input.xlsx')

# %%
df_copy=df.copy()

# %%
df_copy.head()
# Out:
#         Processing date     2023-04-19 00:00:00 Unnamed: 2 Unnamed: 3  \
# 0           File number                     002        NaN        NaN
# 1              FileName  SABR000000119042023002        NaN        NaN
# 2                   NaN                     NaN        NaN        NaN
# 3                Ref no           Issuance Date     Status    IE Code
# 4  SABR0000001000001063     2023-04-21 00:00:00          F  123923443
#
#              Unnamed: 4        Unnamed: 5           Unnamed: 6   Unnamed: 7  \
# 0                   NaN               NaN                  NaN          NaN
# 1                   NaN               NaN                  NaN          NaN
# 2                   NaN               NaN                  NaN          NaN
# 3                Client       Bill Ref no              SB Date  SB Currency
# 4  TEST CLIENT NAME INC  001BCES010200001  2022-11-23 00:00:00          RUB
#
#   Unnamed: 8
# 0        NaN
# 1        NaN
# 2        NaN
# 3  SB Amount
# 4   12505050

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d717c5da-f42f-40aa-8116-20ac9e1848be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d717c5da-f42f-40aa-8116-20ac9e1848be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_copy.columns
# Out:
# Index([  'Processing date', 2023-04-19 00:00:00,        'Unnamed: 2',
#               'Unnamed: 3',        'Unnamed: 4',        'Unnamed: 5',
#               'Unnamed: 6',        'Unnamed: 7',        'Unnamed: 8'],
#       dtype='object')

# %%
df1=pd.read_xml('output_xml.xml')

# %%
df1_copy=df1.copy()

# %%
df1_copy.head()
# Out:
#                  FILENAME  ECERT
# 0  SABR000000119042023002    NaN
# 1                    None    NaN

# %%
df1_copy.columns
# Out:
# Index(['FILENAME', 'ECERT'], dtype='object')

# %%
df1['ECERT'].unique
# Out:
# <bound method Series.unique of 0   NaN
# 1   NaN
# Name: ECERT, dtype: float64>

# %%
df1['FILENAME'].unique
# Out:
# <bound method Series.unique of 0    SABR000000119042023002
# 1                      None
# Name: FILENAME, dtype: object>

# %%
columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4', 'Unnamed: 5','Unnamed: 7']

# %%
df_copy.drop(columns=columns, inplace=True)

# %%
df_copy.columns
# Out:
# Index(['Processing date', 2023-04-19 00:00:00, 'Unnamed: 6', 'Unnamed: 8'], dtype='object')

# %%
df_copy.describe
# Out:
# <bound method NDFrame.describe of          Processing date     2023-04-19 00:00:00           Unnamed: 6  \
# 0            File number                     002                  NaN
# 1               FileName  SABR000000119042023002                  NaN
# 2                    NaN                     NaN                  NaN
# 3                 Ref no           Issuance Date              SB Date
# 4   SABR0000001000001063     2023-04-21 00:00:00  2022-11-23 00:00:00
# 5   SABR0000001000001064     2023-04-21 00:00:00  2022-11-20 00:00:00
# 6   SABR0000001000001065     2023-04-21 00:00:00  2022-11-16 00:00:00
# 7   SABR0000001000001066     2023-04-21 00:00:00  2022-11-21 00:00:00
# 8   SABR0000001000001067     2023-04-21 00:00:00  2022-11-19 00:00:00
# 9   SABR0000001000001068     2023-04-21 00:00:00  2022-11-15 00:00:00
# 10  SABR0000001000001069     2023-04-21 00:00:00  2022-11-03 00:00:00
# 11  SABR0000001000001070     2023-04-21 00:00:00  2022-11-22 00:00:00
# ...

# %%
df_copy=df_copy.rename(columns={'Processing date':'FILENAME' ,'Unnamed: 6': 'SB DATE', 'Unnamed: 8':'ECERT'}, inplace = False)

# %%
df_copy.columns
# Out:
# Index(['FILENAME', 2023-04-19 00:00:00, 'SB DATE', 'ECERT'], dtype='object')

# %%
columns=['FILENAME', 'ECERT']

# %% [markdown]
# Не удалось удалить лишний столбец. Иду дальше

# %%
rates=dict(RUR=1, USD=90.2158)

# %%
df_copy['SVALUEUSD']=df_copy['ECERT'].map(rates)

# %%
df_copy.columns
# Out:
# Index(['FILENAME', 2023-04-19 00:00:00, 'SB DATE', 'ECERT', 'SVALUEUSD'], dtype='object')

# %%
df_copy['ECERT'].unique
# Out:
# <bound method Series.unique of 0             NaN
# 1             NaN
# 2             NaN
# 3       SB Amount
# 4        12505050
# 5       810461.44
# 6     34723261.44
# 7        17388000
# 8        23263950
# 9        19581750
# 10     21392361.6
# 11    10566304.48
# 12     10705226.8
# 13       10973250
# 14       11108700
# 15     5076161.36
# 16     20870116.8
# 17     10661832.8
# 18    16985853.36
# 19      6773332.8
# 20    18844522.64
# 21       17751200
# Name: ECERT, dtype: object>

# %%
df_copy.dropna(subset=['ECERT'],inplace=True)

# %%
df_copy.head()
# Out:
#                FILENAME  2023-04-19 00:00:00              SB DATE  \
# 3                Ref no        Issuance Date              SB Date
# 4  SABR0000001000001063  2023-04-21 00:00:00  2022-11-23 00:00:00
# 5  SABR0000001000001064  2023-04-21 00:00:00  2022-11-20 00:00:00
# 6  SABR0000001000001065  2023-04-21 00:00:00  2022-11-16 00:00:00
# 7  SABR0000001000001066  2023-04-21 00:00:00  2022-11-21 00:00:00
#
#          ECERT  SVALUEUSD
# 3    SB Amount        NaN
# 4     12505050        NaN
# 5    810461.44        NaN
# 6  34723261.44        NaN
# 7     17388000        NaN

# %%
df_copy=df_copy.drop(3)

# %%
df_copy['ECERT']=df_copy['ECERT'].astype(int)

# %%
df_copy['SVALUEUSD']=df_copy['ECERT']/90.2158

# %%
df_copy.head()
# Out:
#                FILENAME  2023-04-19 00:00:00              SB DATE     ECERT  \
# 4  SABR0000001000001063  2023-04-21 00:00:00  2022-11-23 00:00:00  12505050
# 5  SABR0000001000001064  2023-04-21 00:00:00  2022-11-20 00:00:00    810461
# 6  SABR0000001000001065  2023-04-21 00:00:00  2022-11-16 00:00:00  34723261
# 7  SABR0000001000001066  2023-04-21 00:00:00  2022-11-21 00:00:00  17388000
# 8  SABR0000001000001067  2023-04-21 00:00:00  2022-11-19 00:00:00  23263950
#
#        SVALUEUSD
# 4  138612.637698
# 5    8983.581590
# 6  384891.127718
# 7  192737.857448
# 8  257870.018334

# %%
df_copy['SVALUEUSD']=df_copy['SVALUEUSD'].astype(int)

# %%
df_copy['SVALUEUSD']=df_copy['SVALUEUSD'].round(2)

# %%
df_copy.head()
# Out:
#                FILENAME  2023-04-19 00:00:00              SB DATE     ECERT  \
# 4  SABR0000001000001063  2023-04-21 00:00:00  2022-11-23 00:00:00  12505050
# 5  SABR0000001000001064  2023-04-21 00:00:00  2022-11-20 00:00:00    810461
# 6  SABR0000001000001065  2023-04-21 00:00:00  2022-11-16 00:00:00  34723261
# 7  SABR0000001000001066  2023-04-21 00:00:00  2022-11-21 00:00:00  17388000
# 8  SABR0000001000001067  2023-04-21 00:00:00  2022-11-19 00:00:00  23263950
#
#    SVALUEUSD
# 4  138612.64
# 5    8983.58
# 6  384891.13
# 7  192737.86
# 8  257870.02

# %%
df_copy['SB DATE'].unique()
# Out:
# array([datetime.datetime(2022, 11, 23, 0, 0),
#        datetime.datetime(2022, 11, 20, 0, 0),
#        datetime.datetime(2022, 11, 16, 0, 0),
#        datetime.datetime(2022, 11, 21, 0, 0),
#        datetime.datetime(2022, 11, 19, 0, 0),
#        datetime.datetime(2022, 11, 15, 0, 0),
#        datetime.datetime(2022, 11, 3, 0, 0),
#        datetime.datetime(2022, 11, 22, 0, 0),
#        datetime.datetime(2022, 11, 14, 0, 0),
#        datetime.datetime(2022, 11, 9, 0, 0),
#        datetime.datetime(2022, 11, 5, 0, 0)], dtype=object)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e63d185b-1a2a-4678-8581-857cf545bda2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e63d185b-1a2a-4678-8581-857cf545bda2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.read_xml('output_xml_v2.xml')

# %%
df2.head()
# Out:
#                  FILENAME  ECERT
# 0  SABR000000119042023002    NaN
# 1                    None    NaN

# %%
df_copy.iloc[:,1]=df_copy.iloc[:,1].dropna()

# %%
df_copy.iloc[:,1]
# Out:
# 0                        002
# 1     SABR000000119042023002
# 2                        NaN
# 3              Issuance Date
# 4        2023-04-21 00:00:00
# 5        2023-04-21 00:00:00
# 6        2023-04-21 00:00:00
# 7        2023-04-21 00:00:00
# 8        2023-04-21 00:00:00
# 9        2023-04-21 00:00:00
# 10       2023-04-21 00:00:00
# 11       2023-04-21 00:00:00
# 12       2023-04-21 00:00:00
# 13       2023-04-21 00:00:00
# 14       2023-04-21 00:00:00
# 15       2023-04-21 00:00:00
# 16       2023-04-21 00:00:00
# 17       2023-04-21 00:00:00
# 18       2023-04-21 00:00:00
# 19       2023-04-21 00:00:00
# 20       2023-04-21 00:00:00
# 21       2023-04-21 00:00:00
# Name: 2023-04-19 00:00:00, dtype: object

# %%
df_copy.iloc[:,1].drop(3)
# Out:
# 0                        002
# 1     SABR000000119042023002
# 2                        NaN
# 4        2023-04-21 00:00:00
# 5        2023-04-21 00:00:00
# 6        2023-04-21 00:00:00
# 7        2023-04-21 00:00:00
# 8        2023-04-21 00:00:00
# 9        2023-04-21 00:00:00
# 10       2023-04-21 00:00:00
# 11       2023-04-21 00:00:00
# 12       2023-04-21 00:00:00
# 13       2023-04-21 00:00:00
# 14       2023-04-21 00:00:00
# 15       2023-04-21 00:00:00
# 16       2023-04-21 00:00:00
# 17       2023-04-21 00:00:00
# 18       2023-04-21 00:00:00
# 19       2023-04-21 00:00:00
# 20       2023-04-21 00:00:00
# 21       2023-04-21 00:00:00
# Name: 2023-04-19 00:00:00, dtype: object

# %%
df_copy.iloc[:,1].dropna()
# Out:
# 0                        002
# 1     SABR000000119042023002
# 3              Issuance Date
# 4        2023-04-21 00:00:00
# 5        2023-04-21 00:00:00
# 6        2023-04-21 00:00:00
# 7        2023-04-21 00:00:00
# 8        2023-04-21 00:00:00
# 9        2023-04-21 00:00:00
# 10       2023-04-21 00:00:00
# 11       2023-04-21 00:00:00
# 12       2023-04-21 00:00:00
# 13       2023-04-21 00:00:00
# 14       2023-04-21 00:00:00
# 15       2023-04-21 00:00:00
# 16       2023-04-21 00:00:00
# 17       2023-04-21 00:00:00
# 18       2023-04-21 00:00:00
# 19       2023-04-21 00:00:00
# 20       2023-04-21 00:00:00
# 21       2023-04-21 00:00:00
# Name: 2023-04-19 00:00:00, dtype: object

# %%
df_copy=df_copy.rename(columns={df_copy.iloc[:,1]:'SDATE'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-6503cdae821e> in <cell line: 1>()
# ----> 1 df_copy=df_copy.rename(columns={df_copy.iloc[:,1]:'SDATE'}, inplace=True)
#
# TypeError: unhashable type: 'Series'

# %% [markdown]
# Возникла trouble с mappingом данных USD по SDATE

# %%
df.to_excel('test_input.xlsx', index=False)
